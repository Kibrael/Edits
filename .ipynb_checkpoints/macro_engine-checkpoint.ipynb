# %%
##############
#K. David Roell CFPB 7/12/16
#Produces CSV outputs of counts for all macro edit fails
#
##############

import json
import os
import pandas as pd
import psycopg2
#from macro_sql import Q076 
#with open('macro_sql.json') as f: #FIXME change to quality_sql.json and refactor the rest of code
#    edit_sql = json.load(f)
macro_edits = ['Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q015', 'Q016', 'Q023', 'Q031', 'Q047', 'Q048',
              'Q053', 'Q054', 'Q055', 'Q056', 'Q057', 'Q058', 'Q061', 'Q062', 'Q063', 'Q065', 'Q070', 'Q071',
              'Q072', 'Q073', 'Q074', 'Q075', 'Q076', 'Q080', 'Q081', 'Q082', 'Q083']
two_table_edits = ['Q011', 'Q070', 'Q071', 'Q072', 'Q075', 'Q076']
#conn = psycopg2.connect("dbname=hmdamaster user=roellk") #connect and return connection
#cur = conn.cursor()#instantiate cursor object to use in SQL queries
#parameter format for local use #consider changing hmdamaster to roellk if db changes cause a fail
params = {
'dbname':'hmdamaster',
'user':'roellk',
'password':'',
'host':'localhost',

}

#connect_string = "dbname=%s user=%s host=%s password =%s" %(dbname, user, host, password) #set a string for connection to SQL
try:
    conn = psycopg2.connect(**params)
    cur = conn.cursor()
    print("i'm connected")

except psycopg2.Error as e: #if database connection results in an error print the following
    print("I am unable to connect to the database: ", e)



#edit_list = [item for item in dir(SQL_text) if not item.startswith("__")]
# Out:
# i'm connected

# %%
year = 2014 #set start year
while year > 1992: #stop at last table that was loaded
    print(year, '\n', '*'*100)
    table = 'hmdalar' + str(year)
    table_prev = 'hmdalar' + str(year-1)
    first = True
    for edit in macro_edits:
        SQL="" #instantiate empty string

        with open('SQL_files/'+edit+'.sql') as f: #cycle over all SQL files in edit list
            for line in f.readlines():
                SQL = SQL + line.replace('\n', ' ') #add lines from SQL file to string

        SQL = SQL[1:] #remove Byte Order Marker (BOM) from string
        print(edit) #check SQL output
        print() #format spacing
        #if edit in group with 2 tables, execute with 2 table parameters
        if edit in two_table_edits:
            print(SQL.format(table=table, table_prev=table_prev))
            cur.execute(SQL.format(table=table, table_prev=table_prev)) #pass two tables to edits requiring it

        else:
            print(SQL.format(table=table))
            cur.execute(SQL.format(table=table)) #pass single table for most edits

        result_df = pd.DataFrame(cur.fetchall()) #convert query results to dataframe
        col_names = [desc[0] for desc in cur.description] #get list of column names from query result
        print(col_names)
        print(len(result_df.columns))
    #FIXME find out how to label empty df columns IE 58
    #FIXME add in context cols to SQL like denom and numerator
        if len(result_df.columns) == len(col_names): #check if DF is populated with correct number of columns
            print('setting col names')
            result_df.columns = col_names #change DF columns to result names

        if first == True and len(result_df.columns) > 0:
            print('seeding frame')
            first = False
            macro_df = result_df.copy() #seed dataframe with first edit results
        elif first == False and len(result_df.columns) > 0:
            print('merging frames')
            macro_df = macro_df.merge(result_df, how='outer', on=['arid', 'agency'])
        else:
            print("no data returned from query for {edit}".format(edit=edit))

        print(macro_df.head())
    macro_df.year = year
    path = 'macro_csvs/'
    if not os.path.exists(path):
        os.makedirs(path)
    macro_df.to_csv(path + 'macro_'+str(year)+'.csv',index=False)
    year -=1
# Out:
# 2014
#  ****************************************************************************************************
# Q006
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) as numer_count FROM hmdalar2014 WHERE action = '1' AND loan_purpose = '1' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) as denom_count FROM hmdalar2014 WHERE loan_purpose = '1' GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL) *100 AS Q006 FROM numer LEFT JOIN denom on numer.arid = denom.arid WHERE (numer_count/denom_count::REAL) * 100 > 95 AND numer_count > 25;
# ['agency', 'arid', 'q006']
# 3
# setting col names
# seeding frame
#   agency         arid        q006
# 0      1  10000000676   97.826087
# 1      1  10000001154   96.478873
# 2      1  10000004975   95.131086
# 3      1  10000005275  100.000000
# 4      1  10000005842   96.969697
# Q007
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '2' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL) *100 AS Q007 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >15;
# ['agency', 'arid', 'q007']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007
# 0      1  10000000676   97.826087   NaN
# 1      1  10000001154   96.478873   NaN
# 2      1  10000004975   95.131086   NaN
# 3      1  10000005275  100.000000   NaN
# 4      1  10000005842   96.969697   NaN
# Q008
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '4' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM  hmdalar2014 GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q008 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 > 30;
# ['agency', 'arid', 'q008']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008
# 0      1  10000000676   97.826087   NaN   NaN
# 1      1  10000001154   96.478873   NaN   NaN
# 2      1  10000004975   95.131086   NaN   NaN
# 3      1  10000005275  100.000000   NaN   NaN
# 4      1  10000005842   96.969697   NaN   NaN
# Q009
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '5' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q009 FROM numer LEFT JOIN denom on numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >15;
# ['agency', 'arid', 'q009']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009
# 0      1  10000000676   97.826087   NaN   NaN   NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN
# 3      1  10000005275  100.000000   NaN   NaN   NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN
# Q010
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '1' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE action IN ('1','2','3','4','5','6') GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100  AS Q010 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)  * 100< 20;
# ['agency', 'arid', 'q010']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN
# Q011
#
# WITH curr_year AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS curr_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, rid)),  prev_year AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS prev_count FROM hmdalar2013 GROUP BY agency, CONCAT(agency,rid))  SELECT curr_year.agency, curr_year.arid, ((curr_count-prev_count)/prev_count::REAL)*100 AS Q011 FROM curr_year LEFT JOIN prev_year ON curr_year.arid = prev_year.arid WHERE ABS((curr_count-prev_count)/prev_count::REAL)*100 >20 AND (prev_count >=500 or curr_count >=500);
# ['agency', 'arid', 'q011']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
# Q015
#
# WITH numer_count AS(SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE property_type = '3' GROUP BY agency, CONCAT(agency, RID)),  numer_sum AS(SELECT agency ,CONCAT(agency, RID) AS arid ,SUM(amount::INT) AS numer_sum FROM hmdalar2014 WHERE amount NOT ILIKE '%NA%' AND property_type = '3' GROUP BY agency, CONCAT(agency, rid)),  denom_count AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, rid)),  denom_sum AS (SELECT agency ,CONCAT(agency, RID) AS arid ,SUM(amount::INT) AS denom_sum FROM hmdalar2014 WHERE amount NOT ILIKE '%NA%' GROUP BY agency, CONCAT(agency, rid)) SELECT numer_count.agency, numer_count.arid, (numer_count/denom_count::REAL)*100 AS Q015_count, (numer_sum/denom_sum::REAL) * 100 AS Q015_value FROM numer_count LEFT JOIN numer_sum ON numer_count.arid = numer_sum.arid LEFT JOIN denom_count ON numer_count.arid = denom_count.arid LEFT JOIN denom_sum ON numer_count.arid = denom_sum.arid WHERE (numer_count/denom_count::REAL)*100 > 10 OR (numer_sum/denom_sum::REAL)*100 >10 ORDER BY numer_count.agency ASC;
# ['agency', 'arid', 'q015_count', 'q015_value']
# 4
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4    3.333333   12.355103
# Q016
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE income::INT < 10 AND income NOT ILIKE '%NA%' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q016 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >20;
# ['agency', 'arid', 'q016']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016
# 0         NaN         NaN   NaN
# 1         NaN         NaN   NaN
# 2         NaN         NaN   NaN
# 3         NaN         NaN   NaN
# 4    3.333333   12.355103   NaN
# Q023
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE msa ILIKE '%NA%' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q023 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >30;
# ['agency', 'arid', 'q023']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023
# 0         NaN         NaN   NaN        NaN
# 1         NaN         NaN   NaN  63.793103
# 2         NaN         NaN   NaN  50.753769
# 3         NaN         NaN   NaN        NaN
# 4    3.333333   12.355103   NaN        NaN
# Q031
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS multi_count FROM hmdalar2014 WHERE property_type = '3' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,count(sequence) AS total_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, numer.multi_count AS Q031 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom.total_count > 2000 AND numer.multi_count > 200;
# ['agency', 'arid', 'q031']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031
# 0         NaN         NaN   NaN        NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN
# 2         NaN         NaN   NaN  50.753769   NaN
# 3         NaN         NaN   NaN        NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN
# Q047
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE preapproval = '1' AND action = '4' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count/denom_count::real) *100 AS Q047 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::real)*100 > 10;
# ['agency', 'arid', 'q047']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047
# 0         NaN         NaN   NaN        NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN
# Q048
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE preapproval = '1' AND action = '5' GROUP BY agency, concat(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,count(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count/denom_count::real)*100 AS Q048 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::real)*100 >5;
# ['agency', 'arid', 'q048']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN
# Q053
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE agency = '5' AND action = '1' AND hoepa = '1' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q053 FROM numer LEFT JOIN denom on numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 > 1;
# ['agency', 'arid', 'q053']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN
# Q054
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) as numer_count FROM hmdalar2014 WHERE agency = '5' AND action = '6' AND hoepa = '1' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q054 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >1;
# ['agency', 'arid', 'q054']
# 0
# no data returned from query for Q054
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN
# Q055
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE hoepa = '1' AND action = '1' AND rate_spread::REAL >= 5 AND rate_spread NOT ILIKE '%NA%' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE action = '1' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q055 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 > 5;
# ['agency', 'arid', 'q055']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# Q056
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE loan_type = '1' AND loan_purpose = '1' AND action = '3' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE loan_type = '1' AND loan_purpose = '1' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q056 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >70 AND denom_count >=50;
# ['agency', 'arid', 'q056']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055  q056
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Q057
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '3' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, numer_count AS Q057 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom_count >=50 AND numer_count <= 0;
# ['agency', 'arid', 'q057']
# 0
# no data returned from query for Q057
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055  q056
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Q058
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE preapproval = '1' AND action = '7' GROUP BY agency, CONCAT(agency,rid) HAVING COUNT(sequence) = 0),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE preapproval ='1' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, numer_count AS Q058 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom_count >=1000 AND numer_count <= 0;
# ['agency', 'arid', 'q058']
# 0
# no data returned from query for Q058
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055  q056
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Q061
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE property_type = '1' AND lien = '1' AND action = '1' AND rate_spread::REAL > 5 AND rate_spread NOT ILIKE '%NA%' AND rate_spread != '     ' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE action = '1' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q061 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >1;
# ['agency', 'arid', 'q061']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055  \
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN
#
#    q056      q061
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN  1.680672
# 4   NaN       NaN
# Q062
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '1' AND hoepa = '1' AND lien = '1' AND purchaser = '1' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE action = '1' GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q062 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL) *100 >1;
# ['agency', 'arid', 'q062']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  q016       q023  q031  q047  q048  q053  q055  \
# 0         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN   NaN  63.793103   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN   NaN  50.753769   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103   NaN        NaN   NaN   NaN   NaN   NaN   NaN
#
#    q056      q061  q062
# 0   NaN       NaN   NaN
# 1   NaN       NaN   NaN
# 2   NaN       NaN   NaN
# 3   NaN  1.680672   NaN
# 4   NaN       NaN   NaN
# Q063
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2014 WHERE action = '1' AND hoepa = '1' AND lien = '1' AND purchaser = '3' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2014 WHERE action = '1' GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL)*100 AS Q063 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL) * 100 > 1;
# ['agency', 'arid', 'q063']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...        q023  q031  q047  q048  q053  q055  \
# 0         NaN         NaN  ...         NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...   63.793103   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...   50.753769   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...         NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...         NaN   NaN   NaN   NaN   NaN   NaN
#
#    q056      q061  q062  q063
# 0   NaN       NaN   NaN   NaN
# 1   NaN       NaN   NaN   NaN
# 2   NaN       NaN   NaN   NaN
# 3   NaN  1.680672   NaN   NaN
# 4   NaN       NaN   NaN   NaN
#
# [5 rows x 21 columns]
# Q065
#
# SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS Q065 FROM hmdalar2014 WHERE hoepa = '1' GROUP BY agency, CONCAT(agency, rid)  HAVING COUNT(sequence) > 200;
# ['agency', 'arid', 'q065']
# 0
# no data returned from query for Q065
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...        q023  q031  q047  q048  q053  q055  \
# 0         NaN         NaN  ...         NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...   63.793103   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...   50.753769   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...         NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...         NaN   NaN   NaN   NaN   NaN   NaN
#
#    q056      q061  q062  q063
# 0   NaN       NaN   NaN   NaN
# 1   NaN       NaN   NaN   NaN
# 2   NaN       NaN   NaN   NaN
# 3   NaN  1.680672   NaN   NaN
# 4   NaN       NaN   NaN   NaN
#
# [5 rows x 21 columns]
# Q070
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '1' AND purchaser IN ('1','3') GROUP BY agency, CONCAT(agency,rid)),  numer_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type In ('1','2') AND loan_type = '1' AND purchaser IN ('1','3') GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_curr FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '1' GROUP BY agency, CONCAT(agency,rid)),  denom_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '1' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (sold/count_curr::REAL - sold_prev/count_prev::REAL) *100 AS Q070 FROM numer LEFT JOIN numer_prev ON numer.arid = numer_prev.arid LEFT JOIN denom ON denom.arid = numer.arid LEFT JOIN denom_prev ON denom_prev.arid = numer.arid  WHERE (CASE 	    WHEN (sold/count_curr < sold_prev/count_prev) AND ABS(sold/count_curr::REAL - sold_prev/count_prev::REAL) >=10 THEN 1 	    WHEN count_curr >=10000 AND ABS(sold/count_curr::REAL - sold_prev/count_prev::REAL)*100 >=20 THEN 1 	    ELSE NULL END) IS NOT NULL ORDER BY Q070;
# ['agency', 'arid', 'q070']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q031  q047  q048  q053  q055  q056      q061  \
# 0         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN  1.680672
# 4    3.333333   12.355103  ...    NaN   NaN   NaN   NaN   NaN   NaN       NaN
#
#    q062  q063  q070
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 22 columns]
# Q071
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '2' AND purchaser IN ('2') GROUP BY agency, CONCAT(agency,rid)),  numer_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose In ('1','3') AND property_type In ('1','2') AND loan_type = '2' AND purchaser IN ('2') GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_curr FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '2' GROUP BY agency, CONCAT(agency,rid)),  denom_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '2' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, ((sold/count_curr::REAL-sold_prev/count_prev::REAL)*100) AS Q071 FROM numer LEFT JOIN numer_prev ON numer.arid = numer_prev.arid LEFT JOIN denom ON denom.arid = numer.arid LEFT JOIN denom_prev ON denom_prev.arid = numer.arid  WHERE (CASE         WHEN (sold/count_curr < sold_prev/count_prev) AND ABS(sold/count_curr - sold_prev/count_prev) >=10 THEN 1         WHEN count_curr >=2500 AND ABS((sold/count_curr::REAL-sold_prev/count_prev::REAL)*100) >=30 THEN 1         ELSE NULL END) IS NOT NULL ORDER BY Q071 asc;
# ['agency', 'arid', 'q071']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q047  q048  q053  q055  q056      q061  q062  \
# 0         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN       NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN       NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN       NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN  1.680672   NaN
# 4    3.333333   12.355103  ...    NaN   NaN   NaN   NaN   NaN       NaN   NaN
#
#    q063  q070  q071
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 23 columns]
# Q072
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '3' AND purchaser IN ('2') GROUP BY agency, CONCAT(agency,rid)),  numer_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS sold_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type In ('1','2') AND loan_type = '3' AND purchaser IN ('2') GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_curr FROM hmdalar2014 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '3' GROUP BY agency, CONCAT(agency,rid)),  denom_prev AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) AS count_prev FROM hmdalar2013 WHERE action IN ('1','6') AND loan_purpose IN ('1','3') AND property_type IN ('1','2') AND loan_type = '3' GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, ((sold/count_curr::REAL-sold_prev/count_prev::REAL)*100) AS Q072 FROM numer LEFT JOIN numer_prev ON numer.arid = numer_prev.arid LEFT JOIN denom ON denom.arid = numer.arid LEFT JOIN denom_prev ON denom_prev.arid = numer.arid  WHERE (CASE         WHEN (sold/count_curr < sold_prev/count_prev) AND ABS(sold/count_curr - sold_prev/count_prev) >=10 THEN 1         WHEN count_curr >=2000 AND ABS(((sold/count_curr::REAL-sold_prev/count_prev::REAL)*100)) >=30 THEN 1         ELSE NULL END) IS NOT NULL  ORDER BY Q072 asc;
# ['agency', 'arid', 'q072']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q048  q053  q055  q056      q061  q062  q063  \
# 0         NaN         NaN  ...    NaN   NaN   NaN   NaN       NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN   NaN       NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN   NaN       NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN   NaN  1.680672   NaN   NaN
# 4    3.333333   12.355103  ...    NaN   NaN   NaN   NaN       NaN   NaN   NaN
#
#    q070  q071  q072
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 24 columns]
# Q073
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer FROM hmdalar2014 WHERE loan_purpose = '1' AND action IN ('1', '6') AND property_type IN ('1','2') AND loan_type IN ('2','3') AND purchaser != '0' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom FROM hmdalar2014 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') AND loan_type IN ('2','3') GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, numer/denom::REAL*100 Q073  FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom >=250 AND numer/denom::REAL*100 <=20;
# ['agency', 'arid', 'q073']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q053  q055  q056      q061  q062  q063  q070  \
# 0         NaN         NaN  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN  1.680672   NaN   NaN   NaN
# 4    3.333333   12.355103  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
#
#    q071  q072  q073
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 25 columns]
# Q074
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer FROM hmdalar2014 WHERE loan_purpose = '3' AND action IN ('1','6') AND property_type IN ('1','2') AND loan_type IN ('2','3') AND purchaser != '0' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom FROM hmdalar2014 WHERE loan_purpose = '3' AND action IN ('1', '6') AND property_type IN ('1','2') AND loan_type IN ('2', '3') GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, numer/denom::REAL*100 AS Q074 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom >=250 AND numer/denom*100 <=20;
# ['agency', 'arid', 'q074']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q055  q056      q061  q062  q063  q070  q071  \
# 0         NaN         NaN  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN  1.680672   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
#
#    q072  q073  q074
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 26 columns]
# Q075
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_curr FROM hmdalar2014 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') AND purchaser != '0' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_curr FROM hmdalar2014 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') GROUP BY agency, CONCAT(agency, rid)),  numer_prev AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_prev FROM hmdalar2013 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') AND purchaser != '0' GROUP BY agency, CONCAT(agency, rid)),  denom_prev AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_prev FROM hmdalar2013 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_curr/denom_curr::REAL*100 - numer_prev/denom_prev::REAL*100) AS Q075 FROM numer LEFT JOIN denom ON numer.arid = denom.arid LEFT JOIN numer_prev ON numer.arid = numer_prev.arid LEFT JOIN denom_prev ON numer.arid = denom_prev.arid WHERE numer_curr >=750 AND ABS(numer_curr/denom_curr::REAL*100 - numer_prev/denom_prev::REAL*100) >=20;
# ['agency', 'arid', 'q075']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q056      q061  q062  q063  q070  q071  q072  \
# 0         NaN         NaN  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN  1.680672   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
#
#    q073  q074  q075
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 27 columns]
# Q076
#
# WITH sold_curr AS ( SELECT agency, CONCAT(agency, RID) AS ARID, COUNT(sequence) AS sold FROM hmdalar2014 WHERE loan_purpose = '3' AND action IN ( '6') AND property_type IN ('1', '2') GROUP BY agency, CONCAT(agency, RID)),  orig_curr AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS orig FROM hmdalar2014 WHERE loan_purpose = '3' AND action IN ( '1') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID)),  sold_prev AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS sold FROM hmdalar2013 WHERE loan_purpose = '3' AND action IN ( '6') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID)),  orig_prev AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS orig FROM hmdalar2013 WHERE loan_purpose = '3' AND action IN ( '1') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID))  SELECT s.agency, s.arid, (s.sold::REAL/(s.sold::REAL+o.orig::REAL))*100 - (s_prev.sold::REAL/(s_prev.sold::REAL+o_prev.orig::REAL))*100 AS Q076  FROM sold_curr s LEFT JOIN orig_curr o ON o.arid = s.arid LEFT JOIN sold_prev s_prev ON s_prev.arid = s.arid LEFT JOIN orig_prev o_prev on o_prev.arid = s.arid  WHERE (s.sold + o.orig) > 750 AND ABS((s.sold::REAL/(s.sold::REAL+o.orig::REAL))*100 - (s_prev.sold::REAL/(s_prev.sold::REAL+o_prev.orig::REAL))*100) >= 20;
# ['agency', 'arid', 'q076']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...       q061  q062  q063  q070  q071  q072  q073  \
# 0         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...   1.680672   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q074  q075  q076
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 28 columns]
# Q080
#
#  WITH denom AS( 	SELECT 	agency 	,CONCAT(agency, RID) AS arid 	,COUNT(sequence) as denom_count 	FROM hmdalar2014 	WHERE action IN ('1', '2', '3', '4', '5') 	GROUP BY 	agency, CONCAT(agency, RID)),  numer AS ( 	SELECT 	agency 	,CONCAT(agency, RID) AS arid 	,COUNT(sequence) AS numer_count 	FROM hmdalar2014 	WHERE property_type IN ('1', '2') 	AND action IN ('1', '2', '3') 	AND ethnicity IN ('3', '4') 	GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count::REAL / denom_count::REAL) *100 as Q080 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE numer_count::REAL / denom_count::REAL > 50;
# ['agency', 'arid', 'q080']
# 0
# no data returned from query for Q080
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000676   97.826087   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001154   96.478873   NaN   NaN   NaN   NaN        NaN
# 2      1  10000004975   95.131086   NaN   NaN   NaN   NaN -36.012862
# 3      1  10000005275  100.000000   NaN   NaN   NaN   NaN        NaN
# 4      1  10000005842   96.969697   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...       q061  q062  q063  q070  q071  q072  q073  \
# 0         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...   1.680672   NaN   NaN   NaN   NaN   NaN   NaN
# 4    3.333333   12.355103  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q074  q075  q076
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 28 columns]
# Q081
#
# ...
# 1         NaN         NaN  ...    NaN   NaN   NaN  5.996132   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN  4.000000   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...    NaN   NaN   NaN       NaN   NaN   NaN   NaN
#
#    q071  q072  q073
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 25 columns]
# Q074
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer FROM hmdalar2006 WHERE loan_purpose = '3' AND action IN ('1','6') AND property_type IN ('1','2') AND loan_type IN ('2','3') AND purchaser != '0' GROUP BY agency, CONCAT(agency,rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom FROM hmdalar2006 WHERE loan_purpose = '3' AND action IN ('1', '6') AND property_type IN ('1','2') AND loan_type IN ('2', '3') GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, numer/denom::REAL*100 AS Q074 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE denom >=250 AND numer/denom*100 <=20;
# ['agency', 'arid', 'q074']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q055  q056      q061  q062  q065  q070  q071  \
# 0    3.571429    10.63865  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN  5.996132   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN  4.000000   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...    NaN   NaN       NaN   NaN   NaN   NaN   NaN
#
#    q072  q073  q074
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 26 columns]
# Q075
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_curr FROM hmdalar2006 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') AND purchaser != '0' GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_curr FROM hmdalar2006 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') GROUP BY agency, CONCAT(agency, rid)),  numer_prev AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_prev FROM hmdalar2005 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') AND purchaser != '0' GROUP BY agency, CONCAT(agency, rid)),  denom_prev AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS denom_prev FROM hmdalar2005 WHERE loan_purpose = '1' AND action IN ('1','6') AND property_type IN ('1','2') GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_curr/denom_curr::REAL*100 - numer_prev/denom_prev::REAL*100) AS Q075 FROM numer LEFT JOIN denom ON numer.arid = denom.arid LEFT JOIN numer_prev ON numer.arid = numer_prev.arid LEFT JOIN denom_prev ON numer.arid = denom_prev.arid WHERE numer_curr >=750 AND ABS(numer_curr/denom_curr::REAL*100 - numer_prev/denom_prev::REAL*100) >=20;
# ['agency', 'arid', 'q075']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q056      q061  q062  q065  q070  q071  q072  \
# 0    3.571429    10.63865  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN  5.996132   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN  4.000000   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...    NaN       NaN   NaN   NaN   NaN   NaN   NaN
#
#    q073  q074  q075
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 27 columns]
# Q076
#
# WITH sold_curr AS ( SELECT agency, CONCAT(agency, RID) AS ARID, COUNT(sequence) AS sold FROM hmdalar2006 WHERE loan_purpose = '3' AND action IN ( '6') AND property_type IN ('1', '2') GROUP BY agency, CONCAT(agency, RID)),  orig_curr AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS orig FROM hmdalar2006 WHERE loan_purpose = '3' AND action IN ( '1') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID)),  sold_prev AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS sold FROM hmdalar2005 WHERE loan_purpose = '3' AND action IN ( '6') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID)),  orig_prev AS ( SELECT CONCAT(agency, RID) AS ARID, COUNT(sequence) AS orig FROM hmdalar2005 WHERE loan_purpose = '3' AND action IN ( '1') AND property_type IN ('1', '2') GROUP BY CONCAT(agency, RID))  SELECT s.agency, s.arid, (s.sold::REAL/(s.sold::REAL+o.orig::REAL))*100 - (s_prev.sold::REAL/(s_prev.sold::REAL+o_prev.orig::REAL))*100 AS Q076  FROM sold_curr s LEFT JOIN orig_curr o ON o.arid = s.arid LEFT JOIN sold_prev s_prev ON s_prev.arid = s.arid LEFT JOIN orig_prev o_prev on o_prev.arid = s.arid  WHERE (s.sold + o.orig) > 750 AND ABS((s.sold::REAL/(s.sold::REAL+o.orig::REAL))*100 - (s_prev.sold::REAL/(s_prev.sold::REAL+o_prev.orig::REAL))*100) >= 20;
# ['agency', 'arid', 'q076']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...       q061  q062  q065  q070  q071  q072  q073  \
# 0    3.571429    10.63865  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...   5.996132   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...   4.000000   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q074  q075  q076
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 28 columns]
# Q080
#
#  WITH denom AS( 	SELECT 	agency 	,CONCAT(agency, RID) AS arid 	,COUNT(sequence) as denom_count 	FROM hmdalar2006 	WHERE action IN ('1', '2', '3', '4', '5') 	GROUP BY 	agency, CONCAT(agency, RID)),  numer AS ( 	SELECT 	agency 	,CONCAT(agency, RID) AS arid 	,COUNT(sequence) AS numer_count 	FROM hmdalar2006 	WHERE property_type IN ('1', '2') 	AND action IN ('1', '2', '3') 	AND ethnicity IN ('3', '4') 	GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count::REAL / denom_count::REAL) *100 as Q080 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE numer_count::REAL / denom_count::REAL > 50;
# ['agency', 'arid', 'q080']
# 0
# no data returned from query for Q080
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...       q061  q062  q065  q070  q071  q072  q073  \
# 0    3.571429    10.63865  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...   5.996132   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...   4.000000   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q074  q075  q076
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 28 columns]
# Q081
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2006 WHERE action IN ('1', '2', '3') AND property_type IN ('1', '2') AND race IN ('6', '7') GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2006 WHERE action IN ('1', '2', '3', '4', '5') GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, numer_count AS Q081_numer, denom_count AS Q081_denom, (numer_count/denom_count::REAL) *100 AS Q081 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL) *100 >50;
# ['agency', 'arid', 'q081_numer', 'q081_denom', 'q081']
# 5
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q070  q071  q072  q073  q074  q075  q076  \
# 0    3.571429    10.63865  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q081_numer  q081_denom  q081
# 0         NaN         NaN   NaN
# 1         NaN         NaN   NaN
# 2         NaN         NaN   NaN
# 3         NaN         NaN   NaN
# 4         NaN         NaN   NaN
#
# [5 rows x 31 columns]
# Q082
#
# WITH numer AS (SELECT agency ,CONCAT(agency, rid) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2006 WHERE action IN ('1','2','3') AND property_type IN ('1','2') AND sex IN ('3', '4') GROUP BY agency, CONCAT(agency, rid)),  denom AS (SELECT agency ,concat(agency, rid) AS arid ,count(sequence) AS denom_count FROM hmdalar2006 WHERE action IN ('1','2','3','4','5') GROUP BY agency, CONCAT(agency,rid))  SELECT numer.agency, numer.arid, (numer_count::REAL/denom_count *100) AS Q082 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count::REAL/denom_count *100) > 50;
# ['agency', 'arid', 'q082']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value  ...   q071  q072  q073  q074  q075  q076  \
# 0    3.571429    10.63865  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
#
#    q081_numer  q081_denom  q081  q082
# 0         NaN         NaN   NaN   NaN
# 1         NaN         NaN   NaN   NaN
# 2         NaN         NaN   NaN   NaN
# 3         NaN         NaN   NaN   NaN
# 4         NaN         NaN   NaN   NaN
#
# [5 rows x 32 columns]
# Q083
#
# WITH numer AS (SELECT agency ,concat(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2006 WHERE action IN ('1','2','3') AND property_type IN ('1','2') AND ethnicity IN ('3', '4') AND race IN ('6','7') AND sex IN ('3','4') GROUP BY agency, concat(agency, RID)),  denom AS(SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2006 WHERE action IN ('1','2','3','4','5') GROUP BY agency, concat(agency, RID))  SELECT numer.agency, numer.arid, (numer_count::real/denom_count)*100 AS Q083 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count::real/denom_count)*100 > 20;
# ['agency', 'arid', 'q083']
# 3
# setting col names
# merging frames
#   agency         arid        q006  q007  q008  q009  q010       q011  \
# 0      1  10000000086   95.238095   NaN   NaN   NaN   NaN        NaN
# 1      1  10000001493   95.876289   NaN   NaN   NaN   NaN  49.307479
# 2      1  10000003033  100.000000   NaN   NaN   NaN   NaN        NaN
# 3      1  10000003105   95.454545   NaN   NaN   NaN   NaN        NaN
# 4      1  10000003724   97.368421   NaN   NaN   NaN   NaN        NaN
#
#    q015_count  q015_value    ...      q072  q073  q074  q075  q076  \
# 0    3.571429    10.63865    ...       NaN   NaN   NaN   NaN   NaN
# 1         NaN         NaN    ...       NaN   NaN   NaN   NaN   NaN
# 2         NaN         NaN    ...       NaN   NaN   NaN   NaN   NaN
# 3         NaN         NaN    ...       NaN   NaN   NaN   NaN   NaN
# 4         NaN         NaN    ...       NaN   NaN   NaN   NaN   NaN
#
#    q081_numer  q081_denom  q081  q082       q083
# 0         NaN         NaN   NaN   NaN        NaN
# 1         NaN         NaN   NaN   NaN        NaN
# 2         NaN         NaN   NaN   NaN        NaN
# 3         NaN         NaN   NaN   NaN        NaN
# 4         NaN         NaN   NaN   NaN  29.655172
#
# [5 rows x 33 columns]
# 2005
#  ****************************************************************************************************
# Q006
#
# WITH numer AS (SELECT agency ,CONCAT(agency,rid) AS arid ,COUNT(sequence) as numer_count FROM hmdalar2005 WHERE action = '1' AND loan_purpose = '1' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) as denom_count FROM hmdalar2005 WHERE loan_purpose = '1' GROUP BY agency, CONCAT(agency, rid))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL) *100 AS Q006 FROM numer LEFT JOIN denom on numer.arid = denom.arid WHERE (numer_count/denom_count::REAL) * 100 > 95 AND numer_count > 25;
# ['agency', 'arid', 'q006']
# 3
# setting col names
# seeding frame
#   agency         arid        q006
# 0      1  10000000976   96.428571
# 1      1  10000002333   98.529412
# 2      1  10000003286  100.000000
# 3      1  10000003724   96.124031
# 4      1  10000004166   96.761134
# Q007
#
# WITH numer AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS numer_count FROM hmdalar2005 WHERE action = '2' GROUP BY agency, CONCAT(agency, RID)),  denom AS (SELECT agency ,CONCAT(agency, RID) AS arid ,COUNT(sequence) AS denom_count FROM hmdalar2005 GROUP BY agency, CONCAT(agency, RID))  SELECT numer.agency, numer.arid, (numer_count/denom_count::REAL) *100 AS Q007 FROM numer LEFT JOIN denom ON numer.arid = denom.arid WHERE (numer_count/denom_count::REAL)*100 >15;

# %%
#write loop to cycle over hmda macro csv years
#load to dictionary 'year':dataframe
#run script to get aggregates by agency code
#make graphs by agency code over time: 1 agency, edits over time

# %% [markdown]
# #FIXME this is broken due to changes above: exporting to new notebook
# #load all annual CSVs to dictionary
# #create new df copy for summary table
# for key in macro_dfs.keys():
#     summary_df = macro_dfs[key].copy() #copy df to create summary table
# #    print(summary_df.head())
#     #summary_df.drop(['q081_numer', 'q081_denom', 'q015_count'], axis=1, inplace=True)#drop unnecessary columns
#     #summary_df = summary_df.rename(columns={'q015_value':'q015'}) #standardize names
#     print(summary_df.head()) #view df for checking errors
#     #get counts of macro edits by agency code
#     by_agency_df = summary_df.groupby('agency').count() #produce counts of each edit type
#     by_agency_df.drop('arid', axis=1, inplace=True) #drop arid
#
#     #add total index and sum each edit count
#     sum_df = by_agency_df.sum() #put sums of edits in new frame
#     sum_df.name=('total') #name the frame (required to append)
#     by_agency_df = by_agency_df.append(sum_df)
#     by_agency_df['totals'] = by_agency_df.sum(axis=1)
#
#     by_agency_df.to_csv('macro_by_agency_'+str(key)+'.csv') #write to file

# %%
by_agency_df #display df for error checking
# Out:
#         q006  q007  q008  q009  q010  q011  q015_count  q015_value  q016  \
# agency
# 1         21    30    12     8    11   171         235         235     0
# 2         18    16     8     3     4    82         172         172     0
# 3         69    74    41    16    29   326         813         813     3
# 5         40    81    56    39    27   277          36          36     0
# 7         18    25    59    41    31   323          18          18     0
# 9          0     7     2     3     8    80          49          49     0
# total    166   233   178   110   110  1259        1323        1323     3
#
#         q023   ...    q074  q075  q076  q081_numer  q081_denom  q081  q082  \
# agency         ...
# 1        265   ...      13     0     1          40          40    40    36
# 2        167   ...       3     0     1          25          25    25    24
# 3        676   ...       9     0     1         158         158   158   154
# 5        361   ...       0     1     1          29          29    29     6
# 7         66   ...      70     6     9           4           4     4     1
# 9          8   ...      24     5     7           0           0     0     0
# total   1543   ...     119    12    20         256         256   256   221
#
#         q083  counts  totals
# agency
# 1        147     664    2027
# 2        142     420    1331
# 3        686    1906    6244
# 5        101     844    2144
# 7         14     501    1264
# 9         14     120     400
# total   1104    4455   13410
#
# [7 rows x 33 columns]

# %%
##############
#K. David Roell CFPB 7/12/16
#Compiles a report of all quality edit failures for HMDA LAR data
#
##############
import json
import os
import pandas as pd
import psycopg2
#from macro_sql import Q076 
with open('quality_sql.json') as f: #FIXME change to quality_sql.json and refactor the rest of code
    edit_sql = json.load(f)
    
#conn = psycopg2.connect("dbname=hmdamaster user=roellk") #connect and return connection
#cur = conn.cursor()#instantiate cursor object to use in SQL queries
#parameter format for local use #consider changing hmdamaster to roellk if db changes cause a fail
params = {
'dbname':'hmdamaster',
'user':'roellk',
'password':'',
'host':'localhost',

}

#connect_string = "dbname=%s user=%s host=%s password =%s" %(dbname, user, host, password) #set a string for connection to SQL
try:
    conn = psycopg2.connect(**params)
    cur = conn.cursor()
    print("i'm connected")

except psycopg2.Error as e: #if database connection results in an error print the following
    print("I am unable to connect to the database: ", e)


lar_tables = ['hmdalar2014', 'hmdalar2013', 'hmdalar2012', 'hmdalar2011', 'hmdalar2010', 'hmdalar2009'
             ,'hmdalar2008', 'hmdalar2007', 'hmdalar2006', 'hmdalar2005', 'hmdalar2004', 'hmdalar2003'
             ,'hmdalar2002', 'hmdalar2001', 'hmdalar2000', 'hmdalar1999', 'hmdalar1998', 'hmdalar1997'
             ,'hmdalar1996', 'hmdalar1995', 'hmdalar1994', 'hmdalar1993']
# Out:
# i'm connected

# %%
def edit_text(table='hmdalar2014', edit_sql=edit_sql[0]['text'], edit_name=edit_sql[0]['name'], add_fields=[]):
    base_sql = """SELECT year, agency, COUNT(sequence) AS {edit_name} """.format(edit_name=edit_name)
    table_sql = "\nFROM {table}\n".format(table=table) 
    group_sql = """ GROUP BY year, agency"""
    for field in add_fields:
        base_sql = base_sql + ',' + field
        group_sql = group_sql + ', '+ field
    return_sql = base_sql + table_sql + edit_sql + group_sql + ';'
    print(return_sql)
    return return_sql

# %%
fields=['RID']
for table in lar_tables:
    first = True
    for edit in edit_sql:
        name, text = edit['name'], edit['text']
        print(name)
        print(table)
        cur.execute(edit_text(table=table, edit_sql=text, edit_name=name, add_fields=fields))        
        data_df = pd.DataFrame(cur.fetchall())

        col_names = [desc[0] for desc in cur.description]
        if len(data_df.columns) == len(col_names):
            print('setting column names')
            data_df.columns = col_names

        if first == True and len(data_df.columns) > 0:
            quality_df = data_df.copy()
            first = False
                                 
        elif first == False and len(data_df.columns) > 0:
            print('merging dataframes')
            quality_df=quality_df.merge(data_df, how='outer', on=['agency', 'year', 'rid'])
    
        else:
            print('no data returned from query')
        
        print(quality_df.head())

    quality_df['arid'] = quality_df.agency.map(str) + quality_df.rid.map(str)
    quality_df.drop('rid', axis=1, inplace=True)
    path = 'quality_csvs/'
    if not os.path.exists(path):
        os.makedirs(path)
    quality_df.to_csv(path + 'quality_edits' + table[-4:] +'.csv', index=False)
# Out:
# Q035
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q035 ,RID
# FROM hmdalar2014
# WHERE loan_type != '1' AND purchaser IN  ('1','3') GROUP BY year, agency, RID;
# setting column names
#    year agency  q035         rid
# 0  2014      3     3  0000026967
# 1  2014      5     3  0000062542
# 2  2014      1     2  0000014062
# 3  2014      2     2  0000456157
# 4  2014      2     2  0000529958
# Q001
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q001 ,RID
# FROM hmdalar2014
# WHERE amount NOT ILIKE '%NA%' AND income NOT ILIKE '%NA%' AND amount::int >= 1000 AND (amount::int / income::int) >= 5 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001
# 0  2014      3   3.0  0000026967   NaN
# 1  2014      5   3.0  0000062542   NaN
# 2  2014      1   2.0  0000014062   NaN
# 3  2014      2   2.0  0000456157   NaN
# 4  2014      2   2.0  0000529958   NaN
# Q002
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q002 ,RID
# FROM hmdalar2014
# WHERE property_type = '1' AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%' AND income::INT <= 200 AND amount::INT >= 2000 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002
# 0  2014      3   3.0  0000026967   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN
# 3  2014      2   2.0  0000456157   NaN   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN
# Q003
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q003 ,RID
# FROM hmdalar2014
# WHERE loan_type = '2' AND property_type in ('1', '2') AND amount::INT > 626 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN
# Q004
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q004 ,RID
# FROM hmdalar2014
# WHERE loan_type = '3' AND property_type IN ('1', '2') AND amount::INT > 1050 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN
# Q005
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q005 ,RID
# FROM hmdalar2014
# WHERE purchaser IN ('1', '2', '3', '4') AND property_type IN ('1', '2') AND amount::INT > 1203 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN
# Q013
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q013 ,RID
# FROM hmdalar2014
# WHERE property_type = '3' AND (amount::INT <= 100 OR amount::INT >= 10000 AND amount NOT ILIKE '%NA%')  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN
# Q036
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q036 ,RID
# FROM hmdalar2014
# WHERE property_type = '2' AND amount::INT > 150 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Q037
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q037 ,RID
# FROM hmdalar2014
# WHERE lien = '2' AND amount::INT > 250 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037
# 0   2.0
# 1   NaN
# 2   NaN
# 3   1.0
# 4   NaN
# Q038
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q038 ,RID
# FROM hmdalar2014
# WHERE lien = '3' AND amount::INT > 100 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038
# 0   2.0   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   1.0   NaN
# 4   NaN   NaN
# Q025
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q025 ,RID
# FROM hmdalar2014
# WHERE loan_purpose = '1' AND property_type = '1' AND amount::INT <=10 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025
# 0   2.0   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   1.0   NaN   1.0
# 4   NaN   NaN   NaN
# Q068
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q068 ,RID
# FROM hmdalar2014
# WHERE action IN ('1', '2', '3', '4', '5', '7', '8') AND ethnicity = '4' AND race = '7' AND sex = '4' AND co_ethnicity != '5' AND co_race1 != '8' AND co_sex != '5' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068
# 0   2.0   NaN   NaN   2.0
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   1.0   NaN   1.0   3.0
# 4   NaN   NaN   NaN   NaN
# Q014
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q014 ,RID
# FROM hmdalar2014
# WHERE income::INT >= 3000 AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014
# 0   2.0   NaN   NaN   2.0   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   1.0   NaN   1.0   3.0   NaN
# 4   NaN   NaN   NaN   NaN   NaN
# Q024
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q024 ,RID
# FROM hmdalar2014
# WHERE action = '1' AND (amount::INT / income::INT) >= 5 AND income::INT <= 9 AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014  q024
# 0   2.0   NaN   NaN   2.0   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   1.0   NaN   1.0   3.0   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
# Q027
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q027 ,RID
# FROM hmdalar2014
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND property_type IN ('1', '2') AND income ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014  q024  q027
# 0   2.0   NaN   NaN   2.0   NaN   NaN   6.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  43.0
# 3   1.0   NaN   1.0   3.0   NaN   NaN  28.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN  20.0
# Q067
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q067 ,RID
# FROM hmdalar2014
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND ethnicity = '4' AND race = '7' AND sex = '4' AND co_ethnicity = '4' AND co_race1 = '7' AND co_sex = '4' AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014  q024  q027  q067
# 0   2.0   NaN   NaN   2.0   NaN   NaN   6.0   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  43.0   NaN
# 3   1.0   NaN   1.0   3.0   NaN   NaN  28.0   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  20.0   NaN
# Q039
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q039 ,RID
# FROM hmdalar2014
# WHERE hoepa = '1' AND action = '1' AND rate_spread ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014  q024  q027  q067  q039
# 0   2.0   NaN   NaN   2.0   NaN   NaN   6.0   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  43.0   NaN   NaN
# 3   1.0   NaN   1.0   3.0   NaN   NaN  28.0   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  20.0   NaN   NaN
# Q040
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q040 ,RID
# FROM hmdalar2014
# WHERE purchaser IN ('1', '2', '3', '4') AND lien IN ('1', '2') AND (rate_spread NOT ILIKE '%NA%' AND rate_spread::REAL > 10) GROUP BY year, agency, RID;
# no data returned from query
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0   1.0
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    q037  q038  q025  q068  q014  q024  q027  q067  q039
# 0   2.0   NaN   NaN   2.0   NaN   NaN   6.0   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  43.0   NaN   NaN
# 3   1.0   NaN   1.0   3.0   NaN   NaN  28.0   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  20.0   NaN   NaN
# Q066
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q066 ,RID
# FROM hmdalar2014
# WHERE rate_spread NOT ILIKE '%NA%' and rate_spread::REAL >=13 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q037  q038  q025  q068  q014  q024  q027  q067  q039  q066
# 0   2.0   NaN   NaN   2.0   NaN   NaN   6.0   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  43.0   NaN   NaN   NaN
# 3   1.0   NaN   1.0   3.0   NaN   NaN  28.0   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  20.0   NaN   NaN   NaN
#
# [5 rows x 21 columns]
# Q044
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q044 ,RID
# FROM hmdalar2014
# WHERE action = '1' AND lien = '1' AND rate_spread::REAL > 6.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q038  q025  q068  q014  q024  q027  q067  q039  q066  q044
# 0   NaN   NaN   2.0   NaN   NaN   6.0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  43.0   NaN   NaN   NaN   NaN
# 3   NaN   1.0   3.0   NaN   NaN  28.0   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  20.0   NaN   NaN   NaN   NaN
#
# [5 rows x 22 columns]
# Q045
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q045 ,RID
# FROM hmdalar2014
# WHERE action = '1' AND lien = '2' AND rate_spread::REAL > 8.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q025  q068  q014  q024  q027  q067  q039  q066  q044  q045
# 0   NaN   2.0   NaN   NaN   6.0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN  43.0   NaN   NaN   NaN   NaN   NaN
# 3   1.0   3.0   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN  20.0   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 23 columns]
# Q046
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q046 ,RID
# FROM hmdalar2014
# WHERE loan_purpose = '1' AND hoepa = '1' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q068  q014  q024  q027  q067  q039  q066  q044  q045  q046
# 0   2.0   NaN   NaN   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN  43.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   3.0   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN  20.0   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 24 columns]
# Q051
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q051 ,RID
# FROM hmdalar2014
# WHERE ethnicity = '4' AND race = '7' AND sex = '4' AND action = '6' AND hoepa = '1' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q014  q024  q027  q067  q039  q066  q044  q045  q046  q051
# 0   NaN   NaN   6.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN  43.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  20.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 25 columns]
# Q052
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q052 ,RID
# FROM hmdalar2014
# WHERE property_type = '3' AND hoepa = '1'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q024  q027  q067  q039  q066  q044  q045  q046  q051  q052
# 0   NaN   6.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN  43.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  20.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 26 columns]
# Q064
# hmdalar2014
# SELECT year, agency, COUNT(sequence) AS Q064 ,RID
# FROM hmdalar2014
# WHERE purchaser IN ('1', '3') AND hoepa ='1'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2014      3   3.0  0000026967   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2014      5   3.0  0000062542   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2014      1   2.0  0000014062   NaN   NaN   NaN   NaN   NaN   3.0  ...
# 3  2014      2   2.0  0000456157   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 4  2014      2   2.0  0000529958   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q027  q067  q039  q066  q044  q045  q046  q051  q052  q064
# 0   6.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  43.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  20.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 27 columns]
# Q035
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q035 ,RID
# FROM hmdalar2013
# WHERE loan_type != '1' AND purchaser IN  ('1','3') GROUP BY year, agency, RID;
# setting column names
#    year agency  q035         rid
# 0  2013      3     6  0000019006
# 1  2013      1     6  0000014347
# 2  2013      2     7  0000074140
# 3  2013      5     6  0000062352
# 4  2013      3    71  0000019980
# Q001
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q001 ,RID
# FROM hmdalar2013
# WHERE amount NOT ILIKE '%NA%' AND income NOT ILIKE '%NA%' AND amount::int >= 1000 AND (amount::int / income::int) >= 5 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001
# 0  2013      3   6.0  0000019006   NaN
# 1  2013      1   6.0  0000014347   NaN
# 2  2013      2   7.0  0000074140   NaN
# 3  2013      5   6.0  0000062352   NaN
# 4  2013      3  71.0  0000019980   NaN
# Q002
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q002 ,RID
# FROM hmdalar2013
# WHERE property_type = '1' AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%' AND income::INT <= 200 AND amount::INT >= 2000 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002
# 0  2013      3   6.0  0000019006   NaN   NaN
# 1  2013      1   6.0  0000014347   NaN   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN
# 3  2013      5   6.0  0000062352   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN
# Q003
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q003 ,RID
# FROM hmdalar2013
# WHERE loan_type = '2' AND property_type in ('1', '2') AND amount::INT > 626 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN
# Q004
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q004 ,RID
# FROM hmdalar2013
# WHERE loan_type = '3' AND property_type IN ('1', '2') AND amount::INT > 1050 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN
# Q005
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q005 ,RID
# FROM hmdalar2013
# WHERE purchaser IN ('1', '2', '3', '4') AND property_type IN ('1', '2') AND amount::INT > 1203 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN
# Q013
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q013 ,RID
# FROM hmdalar2013
# WHERE property_type = '3' AND (amount::INT <= 100 OR amount::INT >= 10000 AND amount NOT ILIKE '%NA%')  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0
# Q036
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q036 ,RID
# FROM hmdalar2013
# WHERE property_type = '2' AND amount::INT > 150 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# Q037
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q037 ,RID
# FROM hmdalar2013
# WHERE lien = '2' AND amount::INT > 250 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037
# 0   NaN
# 1   NaN
# 2   4.0
# 3   NaN
# 4   NaN
# Q038
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q038 ,RID
# FROM hmdalar2013
# WHERE lien = '3' AND amount::INT > 100 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038
# 0   NaN   1.0
# 1   NaN   NaN
# 2   4.0   NaN
# 3   NaN   NaN
# 4   NaN   NaN
# Q025
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q025 ,RID
# FROM hmdalar2013
# WHERE loan_purpose = '1' AND property_type = '1' AND amount::INT <=10 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025
# 0   NaN   1.0   NaN
# 1   NaN   NaN   NaN
# 2   4.0   NaN   2.0
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
# Q068
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q068 ,RID
# FROM hmdalar2013
# WHERE action IN ('1', '2', '3', '4', '5', '7', '8') AND ethnicity = '4' AND race = '7' AND sex = '4' AND co_ethnicity != '5' AND co_race1 != '8' AND co_sex != '5' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068
# 0   NaN   1.0   NaN   2.0
# 1   NaN   NaN   NaN   NaN
# 2   4.0   NaN   2.0   6.0
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
# Q014
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q014 ,RID
# FROM hmdalar2013
# WHERE income::INT >= 3000 AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068  q014
# 0   NaN   1.0   NaN   2.0   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   4.0   NaN   2.0   6.0   1.0
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
# Q024
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q024 ,RID
# FROM hmdalar2013
# WHERE action = '1' AND (amount::INT / income::INT) >= 5 AND income::INT <= 9 AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068  q014  q024
# 0   NaN   1.0   NaN   2.0   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   4.0   NaN   2.0   6.0   1.0   2.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
# Q027
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q027 ,RID
# FROM hmdalar2013
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND property_type IN ('1', '2') AND income ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068  q014  q024  q027
# 0   NaN   1.0   NaN   2.0   NaN   NaN  38.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN  40.0
# 2   4.0   NaN   2.0   6.0   1.0   2.0  93.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  28.0
# Q067
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q067 ,RID
# FROM hmdalar2013
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND ethnicity = '4' AND race = '7' AND sex = '4' AND co_ethnicity = '4' AND co_race1 = '7' AND co_sex = '4' AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068  q014  q024  q027  q067
# 0   NaN   1.0   NaN   2.0   NaN   NaN  38.0   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  40.0   NaN
# 2   4.0   NaN   2.0   6.0   1.0   2.0  93.0   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  28.0   NaN
# Q039
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q039 ,RID
# FROM hmdalar2013
# WHERE hoepa = '1' AND action = '1' AND rate_spread ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036  \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  19.0
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0   4.0
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0   NaN
#
#    q037  q038  q025  q068  q014  q024  q027  q067  q039
# 0   NaN   1.0   NaN   2.0   NaN   NaN  38.0   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  40.0   NaN   NaN
# 2   4.0   NaN   2.0   6.0   1.0   2.0  93.0   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  28.0   NaN   NaN
# Q040
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q040 ,RID
# FROM hmdalar2013
# WHERE purchaser IN ('1', '2', '3', '4') AND lien IN ('1', '2') AND (rate_spread NOT ILIKE '%NA%' AND rate_spread::REAL > 10) GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q037  q038  q025  q068  q014  q024  q027  q067  q039  q040
# 0   NaN   1.0   NaN   2.0   NaN   NaN  38.0   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  40.0   NaN   NaN   NaN
# 2   4.0   NaN   2.0   6.0   1.0   2.0  93.0   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  28.0   NaN   NaN   NaN
#
# [5 rows x 21 columns]
# Q066
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q066 ,RID
# FROM hmdalar2013
# WHERE rate_spread NOT ILIKE '%NA%' and rate_spread::REAL >=13 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q038  q025  q068  q014  q024  q027  q067  q039  q040  q066
# 0   1.0   NaN   2.0   NaN   NaN  38.0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  40.0   NaN   NaN   NaN   NaN
# 2   NaN   2.0   6.0   1.0   2.0  93.0   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  28.0   NaN   NaN   NaN   NaN
#
# [5 rows x 22 columns]
# Q044
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q044 ,RID
# FROM hmdalar2013
# WHERE action = '1' AND lien = '1' AND rate_spread::REAL > 6.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q025  q068  q014  q024  q027  q067  q039  q040  q066  q044
# 0   NaN   2.0   NaN   NaN  38.0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN  40.0   NaN   NaN   NaN   NaN   NaN
# 2   2.0   6.0   1.0   2.0  93.0   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 23 columns]
# Q045
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q045 ,RID
# FROM hmdalar2013
# WHERE action = '1' AND lien = '2' AND rate_spread::REAL > 8.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q068  q014  q024  q027  q067  q039  q040  q066  q044  q045
# 0   2.0   NaN   NaN  38.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN  40.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   6.0   1.0   2.0  93.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 24 columns]
# Q046
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q046 ,RID
# FROM hmdalar2013
# WHERE loan_purpose = '1' AND hoepa = '1' GROUP BY year, agency, RID;
# no data returned from query
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q068  q014  q024  q027  q067  q039  q040  q066  q044  q045
# 0   2.0   NaN   NaN  38.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN  40.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   6.0   1.0   2.0  93.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 24 columns]
# Q051
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q051 ,RID
# FROM hmdalar2013
# WHERE ethnicity = '4' AND race = '7' AND sex = '4' AND action = '6' AND hoepa = '1' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q014  q024  q027  q067  q039  q040  q066  q044  q045  q051
# 0   NaN   NaN  38.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN  40.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   1.0   2.0  93.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 25 columns]
# Q052
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q052 ,RID
# FROM hmdalar2013
# WHERE property_type = '3' AND hoepa = '1'  GROUP BY year, agency, RID;
# no data returned from query
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q014  q024  q027  q067  q039  q040  q066  q044  q045  q051
# 0   NaN   NaN  38.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN  40.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   1.0   2.0  93.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 25 columns]
# Q064
# hmdalar2013
# SELECT year, agency, COUNT(sequence) AS Q064 ,RID
# FROM hmdalar2013
# WHERE purchaser IN ('1', '3') AND hoepa ='1'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2013      3   6.0  0000019006   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2013      1   6.0  0000014347   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 2  2013      2   7.0  0000074140   NaN   NaN   NaN   NaN   NaN   2.0  ...
# 3  2013      5   6.0  0000062352   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2013      3  71.0  0000019980   NaN   NaN   NaN   NaN   NaN   1.0  ...
#
#    q024  q027  q067  q039  q040  q066  q044  q045  q051  q064
# 0   NaN  38.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN  40.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   2.0  93.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  28.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 26 columns]
# Q035
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q035 ,RID
# FROM hmdalar2012
# WHERE loan_type != '1' AND purchaser IN  ('1','3') GROUP BY year, agency, RID;
# setting column names
#    year agency  q035         rid
# 0  2012      5    14  0000066595
# 1  2012      3     1  0000029141
# 2  2012      5     4  0000009589
# 3  2012      1    12  0000707101
# 4  2012      3     2  0000013290
# Q001
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q001 ,RID
# FROM hmdalar2012
# WHERE amount NOT ILIKE '%NA%' AND income NOT ILIKE '%NA%' AND amount::int >= 1000 AND (amount::int / income::int) >= 5 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001
# 0  2012      5  14.0  0000066595   NaN
# 1  2012      3   1.0  0000029141   NaN
# 2  2012      5   4.0  0000009589   NaN
# 3  2012      1  12.0  0000707101   NaN
# 4  2012      3   2.0  0000013290   NaN
# Q002
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q002 ,RID
# FROM hmdalar2012
# WHERE property_type = '1' AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%' AND income::INT <= 200 AND amount::INT >= 2000 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002
# 0  2012      5  14.0  0000066595   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN
# 2  2012      5   4.0  0000009589   NaN   NaN
# 3  2012      1  12.0  0000707101   NaN   NaN
# 4  2012      3   2.0  0000013290   NaN   NaN
# Q003
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q003 ,RID
# FROM hmdalar2012
# WHERE loan_type = '2' AND property_type in ('1', '2') AND amount::INT > 626 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003
# 0  2012      5  14.0  0000066595   NaN   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN   NaN
# 2  2012      5   4.0  0000009589   NaN   NaN   NaN
# 3  2012      1  12.0  0000707101   NaN   NaN   NaN
# 4  2012      3   2.0  0000013290   NaN   NaN   NaN
# Q004
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q004 ,RID
# FROM hmdalar2012
# WHERE loan_type = '3' AND property_type IN ('1', '2') AND amount::INT > 1050 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004
# 0  2012      5  14.0  0000066595   NaN   NaN   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN   NaN   NaN
# 2  2012      5   4.0  0000009589   NaN   NaN   NaN   NaN
# 3  2012      1  12.0  0000707101   NaN   NaN   NaN   NaN
# 4  2012      3   2.0  0000013290   NaN   NaN   NaN   NaN
# Q005
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q005 ,RID
# FROM hmdalar2012
# WHERE purchaser IN ('1', '2', '3', '4') AND property_type IN ('1', '2') AND amount::INT > 1203 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005
# 0  2012      5  14.0  0000066595   NaN   NaN   NaN   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN   NaN   NaN   NaN
# 2  2012      5   4.0  0000009589   NaN   NaN   NaN   NaN   NaN
# 3  2012      1  12.0  0000707101   NaN   NaN   NaN   NaN   NaN
# 4  2012      3   2.0  0000013290   NaN   NaN   NaN   NaN   NaN
# Q013
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q013 ,RID
# FROM hmdalar2012
# WHERE property_type = '3' AND (amount::INT <= 100 OR amount::INT >= 10000 AND amount NOT ILIKE '%NA%')  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013
# 0  2012      5  14.0  0000066595   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN   NaN   NaN   NaN   1.0
# 2  2012      5   4.0  0000009589   NaN   NaN   NaN   NaN   NaN   NaN
# 3  2012      1  12.0  0000707101   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2012      3   2.0  0000013290   NaN   NaN   NaN   NaN   NaN   1.0
# Q036
# hmdalar2012
# SELECT year, agency, COUNT(sequence) AS Q036 ,RID
# FROM hmdalar2012
# WHERE property_type = '2' AND amount::INT > 150 AND amount NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001  q002  q003  q004  q005  q013  q036
# 0  2012      5  14.0  0000066595   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2012      3   1.0  0000029141   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 2  2012      5   4.0  0000009589   NaN   NaN   NaN   NaN   NaN   NaN   5.0
# ...
# 3   NaN   NaN    4.0   NaN
# 4   2.0   1.0    3.0   6.0
# Q014
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q014 ,RID
# FROM hmdalar2004
# WHERE income::INT >= 3000 AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013   q036  \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  964.0
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN    NaN
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN    1.0
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#    q037  q038   q025  q068  q014
# 0  59.0   NaN  323.0   6.0  99.0
# 1   NaN   NaN    NaN   NaN   NaN
# 2   NaN   NaN    NaN   NaN   1.0
# 3   NaN   NaN    4.0   NaN   NaN
# 4   2.0   1.0    3.0   6.0   1.0
# Q024
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q024 ,RID
# FROM hmdalar2004
# WHERE action = '1' AND (amount::INT / income::INT) >= 5 AND income::INT <= 9 AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013   q036  \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  964.0
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN    NaN
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN    1.0
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#    q037  q038   q025  q068  q014  q024
# 0  59.0   NaN  323.0   6.0  99.0  95.0
# 1   NaN   NaN    NaN   NaN   NaN   NaN
# 2   NaN   NaN    NaN   NaN   1.0   2.0
# 3   NaN   NaN    4.0   NaN   NaN   NaN
# 4   2.0   1.0    3.0   6.0   1.0   NaN
# Q027
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q027 ,RID
# FROM hmdalar2004
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND property_type IN ('1', '2') AND income ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013   q036  \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  964.0
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN    NaN
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN    1.0
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#    q037  q038   q025  q068  q014  q024     q027
# 0  59.0   NaN  323.0   6.0  99.0  95.0  26854.0
# 1   NaN   NaN    NaN   NaN   NaN   NaN      NaN
# 2   NaN   NaN    NaN   NaN   1.0   2.0    241.0
# 3   NaN   NaN    4.0   NaN   NaN   NaN     42.0
# 4   2.0   1.0    3.0   6.0   1.0   NaN     35.0
# Q067
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q067 ,RID
# FROM hmdalar2004
# WHERE action in ('1', '2', '3', '4', '5', '7', '8') AND ethnicity = '4' AND race = '7' AND sex = '4' AND co_ethnicity = '4' AND co_race1 = '7' AND co_sex = '4' AND income NOT ILIKE '%NA%' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013   q036  \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  964.0
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN    NaN
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN    1.0
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#    q037  q038   q025  q068  q014  q024     q027  q067
# 0  59.0   NaN  323.0   6.0  99.0  95.0  26854.0   6.0
# 1   NaN   NaN    NaN   NaN   NaN   NaN      NaN   NaN
# 2   NaN   NaN    NaN   NaN   1.0   2.0    241.0   NaN
# 3   NaN   NaN    4.0   NaN   NaN   NaN     42.0   NaN
# 4   2.0   1.0    3.0   6.0   1.0   NaN     35.0   NaN
# Q039
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q039 ,RID
# FROM hmdalar2004
# WHERE hoepa = '1' AND action = '1' AND rate_spread ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013   q036  \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  964.0
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN    NaN
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN    1.0
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#    q037  q038   q025  q068  q014  q024     q027  q067  q039
# 0  59.0   NaN  323.0   6.0  99.0  95.0  26854.0   6.0   NaN
# 1   NaN   NaN    NaN   NaN   NaN   NaN      NaN   NaN   NaN
# 2   NaN   NaN    NaN   NaN   1.0   2.0    241.0   NaN   NaN
# 3   NaN   NaN    4.0   NaN   NaN   NaN     42.0   NaN   NaN
# 4   2.0   1.0    3.0   6.0   1.0   NaN     35.0   NaN   NaN
# Q040
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q040 ,RID
# FROM hmdalar2004
# WHERE purchaser IN ('1', '2', '3', '4') AND lien IN ('1', '2') AND (rate_spread NOT ILIKE '%NA%' AND rate_spread::REAL > 10) GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q037  q038   q025  q068  q014  q024     q027  q067  q039  q040
# 0  59.0   NaN  323.0   6.0  99.0  95.0  26854.0   6.0   NaN   NaN
# 1   NaN   NaN    NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN
# 2   NaN   NaN    NaN   NaN   1.0   2.0    241.0   NaN   NaN   NaN
# 3   NaN   NaN    4.0   NaN   NaN   NaN     42.0   NaN   NaN   NaN
# 4   2.0   1.0    3.0   6.0   1.0   NaN     35.0   NaN   NaN   NaN
#
# [5 rows x 21 columns]
# Q066
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q066 ,RID
# FROM hmdalar2004
# WHERE rate_spread NOT ILIKE '%NA%' and rate_spread::REAL >=13 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q038   q025  q068  q014  q024     q027  q067  q039  q040  q066
# 0   NaN  323.0   6.0  99.0  95.0  26854.0   6.0   NaN   NaN   1.0
# 1   NaN    NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN
# 2   NaN    NaN   NaN   1.0   2.0    241.0   NaN   NaN   NaN   NaN
# 3   NaN    4.0   NaN   NaN   NaN     42.0   NaN   NaN   NaN   NaN
# 4   1.0    3.0   6.0   1.0   NaN     35.0   NaN   NaN   NaN   5.0
#
# [5 rows x 22 columns]
# Q044
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q044 ,RID
# FROM hmdalar2004
# WHERE action = '1' AND lien = '1' AND rate_spread::REAL > 6.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     q025  q068  q014  q024     q027  q067  q039  q040  q066  q044
# 0  323.0   6.0  99.0  95.0  26854.0   6.0   NaN   NaN   1.0  55.0
# 1    NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   1.0   2.0    241.0   NaN   NaN   NaN   NaN   NaN
# 3    4.0   NaN   NaN   NaN     42.0   NaN   NaN   NaN   NaN   9.0
# 4    3.0   6.0   1.0   NaN     35.0   NaN   NaN   NaN   5.0  69.0
#
# [5 rows x 23 columns]
# Q045
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q045 ,RID
# FROM hmdalar2004
# WHERE action = '1' AND lien = '2' AND rate_spread::REAL > 8.5 AND hoepa != '1' AND rate_spread NOT ILIKE '%NA%'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q068  q014  q024     q027  q067  q039  q040  q066  q044  q045
# 0   6.0  99.0  95.0  26854.0   6.0   NaN   NaN   1.0  55.0  37.0
# 1   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   1.0   2.0    241.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN     42.0   NaN   NaN   NaN   NaN   9.0   1.0
# 4   6.0   1.0   NaN     35.0   NaN   NaN   NaN   5.0  69.0   NaN
#
# [5 rows x 24 columns]
# Q046
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q046 ,RID
# FROM hmdalar2004
# WHERE loan_purpose = '1' AND hoepa = '1' GROUP BY year, agency, RID;
# no data returned from query
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q068  q014  q024     q027  q067  q039  q040  q066  q044  q045
# 0   6.0  99.0  95.0  26854.0   6.0   NaN   NaN   1.0  55.0  37.0
# 1   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   1.0   2.0    241.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN     42.0   NaN   NaN   NaN   NaN   9.0   1.0
# 4   6.0   1.0   NaN     35.0   NaN   NaN   NaN   5.0  69.0   NaN
#
# [5 rows x 24 columns]
# Q051
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q051 ,RID
# FROM hmdalar2004
# WHERE ethnicity = '4' AND race = '7' AND sex = '4' AND action = '6' AND hoepa = '1' GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q014  q024     q027  q067  q039  q040  q066  q044  q045  q051
# 0  99.0  95.0  26854.0   6.0   NaN   NaN   1.0  55.0  37.0   NaN
# 1   NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   1.0   2.0    241.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN     42.0   NaN   NaN   NaN   NaN   9.0   1.0   NaN
# 4   1.0   NaN     35.0   NaN   NaN   NaN   5.0  69.0   NaN   NaN
#
# [5 rows x 25 columns]
# Q052
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q052 ,RID
# FROM hmdalar2004
# WHERE property_type = '3' AND hoepa = '1'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    q024     q027  q067  q039  q040  q066  q044  q045  q051  q052
# 0  95.0  26854.0   6.0   NaN   NaN   1.0  55.0  37.0   NaN   NaN
# 1   NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   2.0    241.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN     42.0   NaN   NaN   NaN   NaN   9.0   1.0   NaN   NaN
# 4   NaN     35.0   NaN   NaN   NaN   5.0  69.0   NaN   NaN   NaN
#
# [5 rows x 26 columns]
# Q064
# hmdalar2004
# SELECT year, agency, COUNT(sequence) AS Q064 ,RID
# FROM hmdalar2004
# WHERE purchaser IN ('1', '3') AND hoepa ='1'  GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency   q035         rid  q001  q002  q003  q004  q005  q013  ...   \
# 0  2004      1  405.0  0000000869  54.0   NaN   2.0   NaN   NaN   3.0  ...
# 1  2004      7    2.0  5140809993   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2004      1  171.0  39-1146835   1.0   NaN   NaN   NaN   NaN   NaN  ...
# 3  2004      4    4.0  0000006081   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2004      3    2.0  0000000324   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       q027  q067  q039  q040  q066  q044  q045  q051  q052  q064
# 0  26854.0   6.0   NaN   NaN   1.0  55.0  37.0   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    241.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     42.0   NaN   NaN   NaN   NaN   9.0   1.0   NaN   NaN   NaN
# 4     35.0   NaN   NaN   NaN   5.0  69.0   NaN   NaN   NaN   NaN
#
# [5 rows x 27 columns]
# Q035
# hmdalar2003
# SELECT year, agency, COUNT(sequence) AS Q035 ,RID
# FROM hmdalar2003
# WHERE loan_type != '1' AND purchaser IN  ('1','3') GROUP BY year, agency, RID;
# setting column names
#    year agency  q035         rid
# 0  2003      7     1  1444800008
# 1  2003      7     6  1531100008
# 2  2003      7     6  7236400005
# 3  2003      7     7  2467100004
# 4  2003      3     5  0000029548
# Q001
# hmdalar2003
# SELECT year, agency, COUNT(sequence) AS Q001 ,RID
# FROM hmdalar2003
# WHERE amount NOT ILIKE '%NA%' AND income NOT ILIKE '%NA%' AND amount::int >= 1000 AND (amount::int / income::int) >= 5 GROUP BY year, agency, RID;
# setting column names
# merging dataframes
#    year agency  q035         rid  q001
# 0  2003      7   1.0  1444800008   NaN
# 1  2003      7   6.0  1531100008   NaN
# 2  2003      7   6.0  7236400005   NaN
# 3  2003      7   7.0  2467100004   NaN
# 4  2003      3   5.0  0000029548   NaN
# Q002
# hmdalar2003
# SELECT year, agency, COUNT(sequence) AS Q002 ,RID
# FROM hmdalar2003
# WHERE property_type = '1' AND income NOT ILIKE '%NA%' AND amount NOT ILIKE '%NA%' AND income::INT <= 200 AND amount::INT >= 2000 GROUP BY year, agency, RID;
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-eab93844f1ad> in <module>()
#       7         print(name)
#       8         print(table)
# ----> 9         cur.execute(edit_text(table=table, edit_sql=text, edit_name=name, add_fields=fields))
#      10         data_df = pd.DataFrame(cur.fetchall())
#      11
#
# ProgrammingError: column "property_type" does not exist
# LINE 3: WHERE property_type = '1' AND income NOT ILIKE '%NA%' AND am...
#               ^

# %%
print('test')
# Out:
# test
